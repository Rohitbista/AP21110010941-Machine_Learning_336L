# %%
import pandas as pd

# %%
df = pd.read_csv("C:/123/SRMAP/Semester 6/Machine Learning Lab/Task 3/tips.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1         NaN  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.shape
# Out:
# (244, 8)

# %%
df['bill_category'] = "NaN"

# %%
df.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2  \
# 1             1         NaN  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
#     bill_category
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# ...

# %%
for i in range(244):
    if(df['total_bill'][i] > 10 and df['tip'][i] > 3):
        df['bill_category'][i] = "Highest-bills-with-tips"
    else:
        df['bill_category'][i] = "Normal-bills"
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17460\24447539.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bill_category'][i] = "Normal-bills"
# C:\Users\User\AppData\Local\Temp\ipykernel_17460\24447539.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bill_category'][i] = "Normal-bills"
# C:\Users\User\AppData\Local\Temp\ipykernel_17460\24447539.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.tail(20)
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 224         224       13.42  1.58    Male    Yes   Fri   Lunch     2  \
# 225         225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226         226         NaN  2.00  Female    Yes   Fri   Lunch     2
# 227         227       20.45  3.00    Male     No   Sat  Dinner     4
# 228         228       13.28  2.72    Male     No   Sat  Dinner     2
# 229         229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230         230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231         231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232         232         NaN  3.39    Male     No   Sat  Dinner     2
# 233         233         NaN  1.47    Male     No   Sat  Dinner     2
# 234         234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235         235         NaN  1.25    Male     No   Sat  Dinner     2
# 236         236         NaN  1.00    Male    Yes   Sat  Dinner     2
# ...
